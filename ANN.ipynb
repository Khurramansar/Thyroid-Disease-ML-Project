# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import SelectKBest, f_classif

# %%
# Load the data
df = pd.read_csv('Thyroid Disease.csv')

# %%
# Data Cleaning
# Handling missing values
imputer = SimpleImputer(strategy='mean')
# Encoding categorical variables
label_encoder = LabelEncoder()

# %%
# Handle non-numeric data
for column in df.columns:
    if df[column].dtype == 'object':
        df[column] = label_encoder.fit_transform(df[column].astype(str))

df_cleaned = imputer.fit_transform(df)

# %%
# Feature Selection
X = df_cleaned[:, :-2]  # Features, excluding Stage and Response
y = df_cleaned[:, -1]   # Response variable

selector = SelectKBest(score_func=f_classif, k=10)
X_selected = selector.fit_transform(X, y)

# Splitting Data
X_train, X_test, y_train, y_test = train_test_split(X_selected, y, test_size=0.2, random_state=42)

# Data Scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Artificial Neural Network (ANN)
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(16, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=50, batch_size=10, verbose=1)

scores = model.evaluate(X_test, y_test)
# Out:
# C:\Users\Global\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7071 - loss: 0.6115
# Epoch 2/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7317 - loss: 0.5903
# Epoch 3/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7130 - loss: 0.5665
# Epoch 4/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7790 - loss: 0.4917
# Epoch 5/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8298 - loss: 0.4373
# Epoch 6/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8232 - loss: 0.3674
# Epoch 7/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8412 - loss: 0.3826
# Epoch 8/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8693 - loss: 0.3430
# Epoch 9/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8884 - loss: 0.3039
# Epoch 10/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8718 - loss: 0.3114
# Epoch 11/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8338 - loss: 0.3377
# Epoch 12/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8706 - loss: 0.2999
# Epoch 13/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8473 - loss: 0.3505
# Epoch 14/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8520 - loss: 0.2975
# Epoch 15/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8770 - loss: 0.2954
# Epoch 16/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8439 - loss: 0.3253
# Epoch 17/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8327 - loss: 0.3228
# Epoch 18/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8775 - loss: 0.2669
# Epoch 19/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8714 - loss: 0.2653
# Epoch 20/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8760 - loss: 0.2854
# Epoch 21/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8601 - loss: 0.2796
# Epoch 22/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8866 - loss: 0.2911
# Epoch 23/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8909 - loss: 0.2661
# Epoch 24/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9100 - loss: 0.2169
# Epoch 25/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8725 - loss: 0.2672
# Epoch 26/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8446 - loss: 0.2771
# Epoch 27/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8900 - loss: 0.2380
# Epoch 28/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8885 - loss: 0.2690
# Epoch 29/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8476 - loss: 0.3482
# Epoch 30/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8609 - loss: 0.2907
# Epoch 31/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8810 - loss: 0.2737
# Epoch 32/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8868 - loss: 0.2931
# Epoch 33/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8953 - loss: 0.2429
# Epoch 34/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8915 - loss: 0.2310
# Epoch 35/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8756 - loss: 0.3007
# Epoch 36/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8808 - loss: 0.2824
# Epoch 37/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8850 - loss: 0.2660
# Epoch 38/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8884 - loss: 0.2823
# Epoch 39/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8770 - loss: 0.2917
# Epoch 40/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8480 - loss: 0.3186
# Epoch 41/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8991 - loss: 0.2148
# Epoch 42/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8936 - loss: 0.2548
# Epoch 43/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9044 - loss: 0.2355
# Epoch 44/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8771 - loss: 0.3099
# Epoch 45/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8518 - loss: 0.3341
# Epoch 46/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8897 - loss: 0.2954
# Epoch 47/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8967 - loss: 0.2353
# Epoch 48/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8881 - loss: 0.2645
# Epoch 49/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8824 - loss: 0.3005
# Epoch 50/50
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9010 - loss: 0.2636
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8869 - loss: 0.2982

# %%
print(f"ANN Accuracy: {scores[1]}")
# Out:
# ANN Accuracy: 0.8831169009208679

# %%
from sklearn.metrics import confusion_matrix, roc_curve, auc, precision_recall_curve

# %%
# Compile model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train model
history = model.fit(X_train, y_train, epochs=50, batch_size=10, validation_split=0.2)

# Predict
y_prob = model.predict(X_test).ravel()
y_pred = (y_prob > 0.5).astype(int)
# Out:
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.8529 - loss: 0.3056 - val_accuracy: 0.8871 - val_loss: 0.3074
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8924 - loss: 0.2439 - val_accuracy: 0.8871 - val_loss: 0.3388
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8902 - loss: 0.2271 - val_accuracy: 0.8871 - val_loss: 0.2920
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8910 - loss: 0.2928 - val_accuracy: 0.9032 - val_loss: 0.2737
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8912 - loss: 0.2503 - val_accuracy: 0.9032 - val_loss: 0.2755
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9019 - loss: 0.2762 - val_accuracy: 0.8871 - val_loss: 0.3101
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9072 - loss: 0.2103 - val_accuracy: 0.9194 - val_loss: 0.2476
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8857 - loss: 0.2609 - val_accuracy: 0.9032 - val_loss: 0.2791
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9162 - loss: 0.2389 - val_accuracy: 0.9032 - val_loss: 0.2699
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8709 - loss: 0.2617 - val_accuracy: 0.9032 - val_loss: 0.2771
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8655 - loss: 0.2714 - val_accuracy: 0.8871 - val_loss: 0.3052
# Epoch 12/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8786 - loss: 0.2468 - val_accuracy: 0.9032 - val_loss: 0.2699
# Epoch 13/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9060 - loss: 0.2252 - val_accuracy: 0.9032 - val_loss: 0.2764
# Epoch 14/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9137 - loss: 0.2089 - val_accuracy: 0.9032 - val_loss: 0.2534
# Epoch 15/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9101 - loss: 0.2327 - val_accuracy: 0.8871 - val_loss: 0.2949
# Epoch 16/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9027 - loss: 0.2345 - val_accuracy: 0.8871 - val_loss: 0.3253
# Epoch 17/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8795 - loss: 0.2329 - val_accuracy: 0.9032 - val_loss: 0.2900
# Epoch 18/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8622 - loss: 0.2740 - val_accuracy: 0.8871 - val_loss: 0.3082
# Epoch 19/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9176 - loss: 0.1829 - val_accuracy: 0.9032 - val_loss: 0.2670
# Epoch 20/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8680 - loss: 0.2818 - val_accuracy: 0.8226 - val_loss: 0.4465
# Epoch 21/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8834 - loss: 0.2870 - val_accuracy: 0.8387 - val_loss: 0.3579
# Epoch 22/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8580 - loss: 0.3050 - val_accuracy: 0.8871 - val_loss: 0.3278
# Epoch 23/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8585 - loss: 0.2734 - val_accuracy: 0.9032 - val_loss: 0.2793
# Epoch 24/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8969 - loss: 0.2165 - val_accuracy: 0.8871 - val_loss: 0.3165
# Epoch 25/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8990 - loss: 0.2216 - val_accuracy: 0.9032 - val_loss: 0.2741
# Epoch 26/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8753 - loss: 0.2788 - val_accuracy: 0.8871 - val_loss: 0.3360
# Epoch 27/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9264 - loss: 0.2160 - val_accuracy: 0.8871 - val_loss: 0.3238
# Epoch 28/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9172 - loss: 0.2065 - val_accuracy: 0.8871 - val_loss: 0.2609
# Epoch 29/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8939 - loss: 0.2667 - val_accuracy: 0.8871 - val_loss: 0.3015
# Epoch 30/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8868 - loss: 0.2655 - val_accuracy: 0.9032 - val_loss: 0.2861
# Epoch 31/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8928 - loss: 0.2797 - val_accuracy: 0.8871 - val_loss: 0.3096
# Epoch 32/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8578 - loss: 0.2778 - val_accuracy: 0.8226 - val_loss: 0.3699
# Epoch 33/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8953 - loss: 0.2731 - val_accuracy: 0.9032 - val_loss: 0.2924
# Epoch 34/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8543 - loss: 0.2994 - val_accuracy: 0.8871 - val_loss: 0.3312
# Epoch 35/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8952 - loss: 0.2073 - val_accuracy: 0.8871 - val_loss: 0.3195
# Epoch 36/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8665 - loss: 0.2915 - val_accuracy: 0.8871 - val_loss: 0.3250
# Epoch 37/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9138 - loss: 0.2117 - val_accuracy: 0.9032 - val_loss: 0.2798
# Epoch 38/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9255 - loss: 0.2261 - val_accuracy: 0.8065 - val_loss: 0.4201
# Epoch 39/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9006 - loss: 0.2113 - val_accuracy: 0.9032 - val_loss: 0.2683
# Epoch 40/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8524 - loss: 0.3392 - val_accuracy: 0.8871 - val_loss: 0.3382
# Epoch 41/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9051 - loss: 0.2386 - val_accuracy: 0.8871 - val_loss: 0.2706
# Epoch 42/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8854 - loss: 0.2831 - val_accuracy: 0.8226 - val_loss: 0.3907
# Epoch 43/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8522 - loss: 0.2849 - val_accuracy: 0.8710 - val_loss: 0.3397
# Epoch 44/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8886 - loss: 0.2369 - val_accuracy: 0.8226 - val_loss: 0.3931
# Epoch 45/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8771 - loss: 0.2344 - val_accuracy: 0.9032 - val_loss: 0.2767
# Epoch 46/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9002 - loss: 0.2349 - val_accuracy: 0.8387 - val_loss: 0.3738
# Epoch 47/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8888 - loss: 0.2436 - val_accuracy: 0.9032 - val_loss: 0.2934
# Epoch 48/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8952 - loss: 0.2512 - val_accuracy: 0.8871 - val_loss: 0.3349
# Epoch 49/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8947 - loss: 0.2478 - val_accuracy: 0.9032 - val_loss: 0.2939
# Epoch 50/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9061 - loss: 0.2143 - val_accuracy: 0.8871 - val_loss: 0.3361
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('ANN Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
# ROC Curve and AUC
fpr, tpr, _ = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ANN Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %%
# Precision-Recall Curve
precision, recall, _ = precision_recall_curve(y_test, y_prob)
plt.figure(figsize=(8, 6))
plt.plot(recall, precision, color='blue', lw=2)
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('ANN Precision-Recall Curve')
plt.show()

# %%
# Learning Curves
plt.figure(figsize=(12, 8))
plt.plot(history.history['accuracy'], label='Training accuracy')
plt.plot(history.history['val_accuracy'], label='Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('ANN Learning Curves')
plt.legend()
plt.show()
